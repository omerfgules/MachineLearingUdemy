# %%
import pandas as pd

# %%
import numpy as np

# %%
data=np.random.randn(4,3)

# %%
data
# Out:
# array([[ 2.51314972,  1.43642509,  0.90057807],
#        [ 0.14260263,  0.36222747, -0.03944065],
#        [ 1.83647359,  1.09013208, -2.86410608],
#        [ 2.58318762,  1.86453847,  2.89330309]])

# %%
data_frame=pd.DataFrame(data)

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df=pd.DataFrame(data,index=["name1","name2","name3","name4"],columns=["SAlary","Age","Seniority"])

# %%
new_df
# Out:
#          SAlary       Age  Seniority
# name1  2.513150  1.436425   0.900578
# name2  0.142603  0.362227  -0.039441
# name3  1.836474  1.090132  -2.864106
# name4  2.583188  1.864538   2.893303

# %%
new_df["SAlary"]
# Out:
# name1    2.513150
# name2    0.142603
# name3    1.836474
# name4    2.583188
# Name: SAlary, dtype: float64

# %%
new_df[["Age","SAlary"]]
# Out:
#             Age    SAlary
# name1  1.436425  2.513150
# name2  0.362227  0.142603
# name3  1.090132  1.836474
# name4  1.864538  2.583188

# %%
new_df.loc["name1"]
# Out:
# SAlary       2.513150
# Age          1.436425
# Seniority    0.900578
# Name: name1, dtype: float64

# %%
new_df.loc["name2"]
# Out:
# SAlary       0.142603
# Age          0.362227
# Seniority   -0.039441
# Name: name2, dtype: float64

# %%
new_df.iloc[0]
# Out:
# SAlary       2.513150
# Age          1.436425
# Seniority    0.900578
# Name: name1, dtype: float64
